# %% [markdown]
# <a href="https://colab.research.google.com/github/360DigiTMG-Training/DataScience/blob/main/Pythoncodes/Hierarchical%20Template2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import necessary packages

# %%
import pandas
import matplotlib.pylab
from scipy.cluster.hierarchy import linkage,fcluster
import scipy.cluster.hierarchy
from sklearn.cluster import AgglomerativeClustering

# %% [markdown]
# # Import Datatset

# %%
df = pd.read_csv("")

# %% [markdown]
# # Pre-processing

# %% [markdown]
# # Checking Missing values (na)

# %%
df.isna.sum()

# %% [markdown]
# # Outlier Analysis - Use boxplot and treat the outliers

# %% [markdown]
# # Standardization or Normalization

# %%
def std_fnc(i):
    x=(i-i.min())/(i.std())
    return(x)
std_df = std_fnc()

# %% [markdown]
# # Create dummy variable for categorical columns (If any)

# %%
df.info()

df_dummy = pd.get_dummies()

# %% [markdown]
# # Hierarchical Clustering - Agglomerative Clustering

# %%
# create the linkage of the data.
z = linkage()

# %%
# Plot the figure for dendodram
plt.figure()
scipy.cluster.hierarchy.dendrogram()
plt.show()

# %%
# Create labels for data as per grouping
df_comp = AgglomerativeClustering() #complete linkage with euclidean affinity
df_comp.labels_

# %%
# Make the lables to series format
at_cluster_column = pd.Series()
